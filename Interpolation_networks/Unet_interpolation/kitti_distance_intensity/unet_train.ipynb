# %% [markdown]
# A diferencia de 3.2_kitti_carla, se disminuyó el dropout rate de 0.5 a 0.25 y se agregaron más capas de dropout

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import imageio.v2 as io
import cv2

from data_gen import *
from unet_model_2ch import *
# Out:
# Total distance images: 4925
# Train distance images: 4432
# Validation distance images: 493
# ****************************************
# Input image resolution: 16 x 1024 x 2
# Output image resolution: 64 x 1024 x 2
# Upscaling factor: x4
# ****************************************

# %% [markdown]
# ### Configuración GPU

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print(tf.config.list_physical_devices('GPU'))

#Hacer que tf vaya asignando solo la cantidad de memoria requerida
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# Num GPUs Available:  1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Generación del dataset de entrenamiento y prueba

# %% [markdown]
# ### Empleando generadores

# %%
batch_size=8

#Training dataset
train_dataset_example = tf.data.Dataset.from_generator(generator=train_data_generator, output_types=(tf.float32, tf.float32))
train_dataset_example = train_dataset_example.batch(batch_size)

#Validation dataset
valid_dataset_example = tf.data.Dataset.from_generator(generator=valid_data_generator, output_types=(tf.float32, tf.float32))
valid_dataset_example = valid_dataset_example.batch(batch_size)


for a, b in valid_dataset_example.take(1):
    print(a.shape)
    print(b.shape)
    #plt.figure(figsize=(20,20))
    #plt.imshow(a[0], cmap='jet')
    #plt.figure(figsize=(20,20))
    #plt.imshow(b[0], cmap='jet')
    #plt.show()

#Test dataset
#test_dataset_example = tf.data.Dataset.from_generator(generator=test_data_generator, output_types=(tf.float32, tf.float32))
#test_dataset_example = test_dataset_example.batch(batch_size)
# Out:
# (8, 16, 1024, 2)
# (8, 64, 1024)

# %% [markdown]
# ## Modelo

# %%
model = Unet()
model.summary()

#from keras.utils.vis_utils import plot_model
#plot_model(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 16, 1024, 2  0           []
#                                 )]
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 1024, 64  1216       ['input_1[0][0]']
#  ose)                           )
#
#  batch_normalization (BatchNorm  (None, 32, 1024, 64  256        ['conv2d_transpose[0][0]']
#  alization)                     )
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 1024, 64  36928      ['batch_normalization[0][0]']
#  spose)                         )
#
#  batch_normalization_1 (BatchNo  (None, 64, 1024, 64  256        ['conv2d_transpose_1[0][0]']
#  rmalization)                   )
#
#  conv2d (Conv2D)                (None, 64, 1024, 64  36928       ['batch_normalization_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 64, 1024, 64  256        ['conv2d[0][0]']
#  rmalization)                   )
#
#  conv2d_1 (Conv2D)              (None, 64, 1024, 64  36928       ['batch_normalization_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 64, 1024, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  average_pooling2d (AveragePool  (None, 32, 512, 64)  0          ['batch_normalization_3[0][0]']
#  ing2D)
#
#  monte_carlo_dropout (MonteCarl  (None, 32, 512, 64)  0          ['average_pooling2d[0][0]']
#  oDropout)
#
#  conv2d_2 (Conv2D)              (None, 32, 512, 128  73856       ['monte_carlo_dropout[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 32, 512, 128  512        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  conv2d_3 (Conv2D)              (None, 32, 512, 128  147584      ['batch_normalization_4[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 32, 512, 128  512        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  average_pooling2d_1 (AveragePo  (None, 16, 256, 128  0          ['batch_normalization_5[0][0]']
#  oling2D)                       )
#
#  monte_carlo_dropout_1 (MonteCa  (None, 16, 256, 128  0          ['average_pooling2d_1[0][0]']
#  rloDropout)                    )
#
#  conv2d_4 (Conv2D)              (None, 16, 256, 256  295168      ['monte_carlo_dropout_1[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 16, 256, 256  1024       ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  conv2d_5 (Conv2D)              (None, 16, 256, 256  590080      ['batch_normalization_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 16, 256, 256  1024       ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  average_pooling2d_2 (AveragePo  (None, 8, 128, 256)  0          ['batch_normalization_7[0][0]']
#  oling2D)
#
#  monte_carlo_dropout_2 (MonteCa  (None, 8, 128, 256)  0          ['average_pooling2d_2[0][0]']
#  rloDropout)
#
#  conv2d_6 (Conv2D)              (None, 8, 128, 512)  1180160     ['monte_carlo_dropout_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 128, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 8, 128, 512)  2359808     ['batch_normalization_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 128, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  average_pooling2d_3 (AveragePo  (None, 4, 64, 512)  0           ['batch_normalization_9[0][0]']
#  oling2D)
#
#  monte_carlo_dropout_3 (MonteCa  (None, 4, 64, 512)  0           ['average_pooling2d_3[0][0]']
#  rloDropout)
#
#  conv2d_8 (Conv2D)              (None, 4, 64, 1024)  4719616     ['monte_carlo_dropout_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 4, 64, 1024)  4096       ['conv2d_8[0][0]']
#  ormalization)
#
#  conv2d_9 (Conv2D)              (None, 4, 64, 1024)  9438208     ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 4, 64, 1024)  4096       ['conv2d_9[0][0]']
#  ormalization)
#
#  monte_carlo_dropout_4 (MonteCa  (None, 4, 64, 1024)  0          ['batch_normalization_11[0][0]']
#  rloDropout)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 8, 128, 512)  4719104    ['monte_carlo_dropout_4[0][0]']
#  spose)
#
#  batch_normalization_12 (BatchN  (None, 8, 128, 512)  2048       ['conv2d_transpose_2[0][0]']
#  ormalization)
#
#  concatenate (Concatenate)      (None, 8, 128, 1024  0           ['batch_normalization_9[0][0]',
#                                 )                                 'batch_normalization_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 128, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 128, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 8, 128, 512)  2359808     ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 8, 128, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  monte_carlo_dropout_5 (MonteCa  (None, 8, 128, 512)  0          ['batch_normalization_14[0][0]']
#  rloDropout)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 16, 256, 256  1179904    ['monte_carlo_dropout_5[0][0]']
#  spose)                         )
#
#  batch_normalization_15 (BatchN  (None, 16, 256, 256  1024       ['conv2d_transpose_3[0][0]']
#  ormalization)                  )
#
#  concatenate_1 (Concatenate)    (None, 16, 256, 512  0           ['batch_normalization_7[0][0]',
#                                 )                                 'batch_normalization_15[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 256, 256  1179904     ['concatenate_1[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 16, 256, 256  1024       ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  conv2d_13 (Conv2D)             (None, 16, 256, 256  590080      ['batch_normalization_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 16, 256, 256  1024       ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  monte_carlo_dropout_6 (MonteCa  (None, 16, 256, 256  0          ['batch_normalization_17[0][0]']
#  rloDropout)                    )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 512, 128  295040     ['monte_carlo_dropout_6[0][0]']
#  spose)                         )
#
#  batch_normalization_18 (BatchN  (None, 32, 512, 128  512        ['conv2d_transpose_4[0][0]']
#  ormalization)                  )
#
#  concatenate_2 (Concatenate)    (None, 32, 512, 256  0           ['batch_normalization_5[0][0]',
#                                 )                                 'batch_normalization_18[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 512, 128  295040      ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 32, 512, 128  512        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  conv2d_15 (Conv2D)             (None, 32, 512, 128  147584      ['batch_normalization_19[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 32, 512, 128  512        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  monte_carlo_dropout_7 (MonteCa  (None, 32, 512, 128  0          ['batch_normalization_20[0][0]']
#  rloDropout)                    )
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 1024, 64  73792      ['monte_carlo_dropout_7[0][0]']
#  spose)                         )
#
#  batch_normalization_21 (BatchN  (None, 64, 1024, 64  256        ['conv2d_transpose_5[0][0]']
#  ormalization)                  )
#
#  concatenate_3 (Concatenate)    (None, 64, 1024, 12  0           ['batch_normalization_3[0][0]',
#                                 8)                                'batch_normalization_21[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 1024, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 64, 1024, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  conv2d_17 (Conv2D)             (None, 64, 1024, 64  36928       ['batch_normalization_22[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 64, 1024, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 64, 1024, 1)  65          ['batch_normalization_23[0][0]']
#
# ==================================================================================================
# Total params: 34,614,529
# Trainable params: 34,600,577
# Non-trainable params: 13,952
# __________________________________________________________________________________________________

# %% [markdown]
# ## Entrenamiento con generadores

# %%
def get_check_callback():
    path_check_folder = os.path.join(path_folder, r'LIDAR_super_resolution\Scripts\unet\3_model_fit_keras\3.6_kitti_distance_intensity\model_mae')
    path_csv_check = os.path.join(path_folder, r'LIDAR_super_resolution\Scripts\unet\3_model_fit_keras\3.6_kitti_distance_intensity\model_mae\csv_train.csv')
    #tensorboard_logs_folder = os.path.join(path_folder, r'LIDAR_super_resolution\Scripts\unet_based\checkpoints3\tensorboard_logs')
   
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(path_check_folder,'best_{epoch:02d}_{val_loss:.4f}.h5'),#path_check_folder,
                                                                   save_weights_only=False,
                                                                   monitor='val_loss',
                                                                   verbose=0,
                                                                   mode='min',
                                                                   save_best_only=True)
    csv_logger = keras.callbacks.CSVLogger(path_csv_check)
    
    #tensorboard_model = keras.callbacks.TensorBoard(log_dir=tensorboard_logs_folder)
    #command = 'tensorboard --logdir=' + os.path.join(tensorboard_logs_folder, 'logs') + ' &'
    #os.system(command)     
    
    return model_checkpoint_callback, csv_logger#, tensorboard_model

epochs = 200
batch_size=16

def train():

    train_dataset = tf.data.Dataset.from_generator(generator=train_data_generator, output_types=(tf.float32, tf.float32))
    train_dataset = train_dataset.batch(batch_size)
    train_dataset = train_dataset.__iter__()

    valid_dataset = tf.data.Dataset.from_generator(generator=valid_data_generator, output_types=(tf.float32, tf.float32))
    valid_dataset = valid_dataset.batch(batch_size)
    valid_dataset = valid_dataset.__iter__()
    
    #model_checkpoint_callback, csv_logger, tensorboard_model = get_check_callback()
    model_checkpoint_callback, csv_logger = get_check_callback()

    model.fit(train_dataset,
              validation_data=valid_dataset,
              validation_steps=round(len(valid_urls)/batch_size),
              epochs=epochs,
              steps_per_epoch=round(len(train_urls)/batch_size),
              verbose=1,
              #callbacks=[model_checkpoint_callback, csv_logger, tensorboard_model])
              callbacks=[model_checkpoint_callback, csv_logger])

train()
model.save(os.path.join(path_folder, r'LIDAR_super_resolution\Scripts\unet\3_model_fit_keras\3.6_kitti_distance_intensity\model_mae\final.h5'))
# Out:
# Epoch 1/200
# 277/277 [==============================] - 230s 763ms/step - loss: 0.0627 - val_loss: 0.0818
# Epoch 2/200
# 277/277 [==============================] - 211s 763ms/step - loss: 0.0239 - val_loss: 0.0441
# Epoch 3/200
# 277/277 [==============================] - 210s 757ms/step - loss: 0.0181 - val_loss: 0.6604
# Epoch 4/200
# 277/277 [==============================] - 212s 764ms/step - loss: 0.0163 - val_loss: 0.0204
# Epoch 5/200
# 277/277 [==============================] - 211s 763ms/step - loss: 0.0165 - val_loss: 0.0196
# Epoch 6/200
# 277/277 [==============================] - 211s 763ms/step - loss: 0.0165 - val_loss: 0.0160
# Epoch 7/200
# 277/277 [==============================] - 210s 758ms/step - loss: 0.0148 - val_loss: 0.0199
# Epoch 8/200
# 277/277 [==============================] - 210s 759ms/step - loss: 0.0143 - val_loss: 0.0172
# Epoch 9/200
# 277/277 [==============================] - 209s 756ms/step - loss: 0.0141 - val_loss: 0.0160
# Epoch 10/200
# 277/277 [==============================] - 206s 744ms/step - loss: 0.0140 - val_loss: 0.0207
# Epoch 11/200
# 277/277 [==============================] - 206s 744ms/step - loss: 0.0130 - val_loss: 0.0183
# Epoch 12/200
# 277/277 [==============================] - 197s 712ms/step - loss: 0.0133 - val_loss: 0.0184
# Epoch 13/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0135 - val_loss: 0.0154
# Epoch 14/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0127 - val_loss: 0.0134
# Epoch 15/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0127 - val_loss: 0.0188
# Epoch 16/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0131 - val_loss: 0.0323
# Epoch 17/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0132 - val_loss: 0.0147
# Epoch 18/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0123 - val_loss: 0.0125
# Epoch 19/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0121 - val_loss: 0.0129
# Epoch 20/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0120 - val_loss: 0.0135
# Epoch 21/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0116 - val_loss: 0.0117
# Epoch 22/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0118 - val_loss: 0.0128
# Epoch 23/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0122 - val_loss: 0.0132
# Epoch 24/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0117 - val_loss: 0.0119
# Epoch 25/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0114 - val_loss: 0.0112
# Epoch 26/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0117 - val_loss: 0.0159
# Epoch 27/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0119 - val_loss: 0.0128
# Epoch 28/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0116 - val_loss: 0.0114
# Epoch 29/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0114 - val_loss: 0.0125
# Epoch 30/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0110 - val_loss: 0.0123
# Epoch 31/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0109 - val_loss: 0.0114
# Epoch 32/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0108 - val_loss: 0.0108
# Epoch 33/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0109 - val_loss: 0.0123
# Epoch 34/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0107 - val_loss: 0.0116
# Epoch 35/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0106 - val_loss: 0.0110
# Epoch 36/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0107 - val_loss: 0.0115
# Epoch 37/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0105 - val_loss: 0.0113
# Epoch 38/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0104 - val_loss: 0.0117
# Epoch 39/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0103 - val_loss: 0.0106
# Epoch 40/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0103 - val_loss: 0.0109
# Epoch 41/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0103 - val_loss: 0.0112
# Epoch 42/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 43/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0102 - val_loss: 0.0108
# Epoch 44/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 45/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0100 - val_loss: 0.0114
# Epoch 46/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0102 - val_loss: 0.0100
# Epoch 47/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0101 - val_loss: 0.0116
# Epoch 48/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0101 - val_loss: 0.0106
# Epoch 49/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0109 - val_loss: 0.0133
# Epoch 50/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0107 - val_loss: 0.0112
# Epoch 51/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0104 - val_loss: 0.0101
# Epoch 52/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0103 - val_loss: 0.0108
# Epoch 53/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 54/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 55/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0099 - val_loss: 0.0098
# Epoch 56/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0099 - val_loss: 0.0097
# Epoch 57/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0097 - val_loss: 0.0097
# Epoch 58/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0097 - val_loss: 0.0101
# Epoch 59/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0096 - val_loss: 0.0099
# Epoch 60/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0098 - val_loss: 0.0097
# Epoch 61/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0096 - val_loss: 0.0101
# Epoch 62/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0097 - val_loss: 0.0104
# Epoch 63/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0095 - val_loss: 0.0105
# Epoch 64/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0095 - val_loss: 0.0105
# Epoch 65/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0097 - val_loss: 0.0101
# Epoch 66/200
# 277/277 [==============================] - 198s 714ms/step - loss: 0.0095 - val_loss: 0.0094
# Epoch 67/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0095 - val_loss: 0.0099
# Epoch 68/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0094 - val_loss: 0.0094
# Epoch 69/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0094 - val_loss: 0.0094
# Epoch 70/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0093 - val_loss: 0.0098
# Epoch 71/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0094 - val_loss: 0.0121
# Epoch 72/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 73/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 74/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0092 - val_loss: 0.0097
# Epoch 75/200
# 277/277 [==============================] - 198s 714ms/step - loss: 0.0092 - val_loss: 0.0092
# Epoch 76/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0092 - val_loss: 0.0103
# Epoch 77/200
# 277/277 [==============================] - 198s 715ms/step - loss: 0.0093 - val_loss: 0.0091
# Epoch 78/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0091 - val_loss: 0.0095
# Epoch 79/200
# 277/277 [==============================] - 197s 709ms/step - loss: 0.0091 - val_loss: 0.0093
# Epoch 80/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 81/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0092 - val_loss: 0.0092
# Epoch 82/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0091 - val_loss: 0.0092
# Epoch 83/200
# 277/277 [==============================] - 197s 709ms/step - loss: 0.0091 - val_loss: 0.0131
# Epoch 84/200
# 277/277 [==============================] - 198s 714ms/step - loss: 0.0092 - val_loss: 0.0090
# Epoch 85/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0090 - val_loss: 0.0093
# Epoch 86/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0090 - val_loss: 0.0100
# Epoch 87/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0089 - val_loss: 0.0091
# Epoch 88/200
# 277/277 [==============================] - 198s 714ms/step - loss: 0.0091 - val_loss: 0.0090
# Epoch 89/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0088 - val_loss: 0.0093
# Epoch 90/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0089 - val_loss: 0.0095
# Epoch 91/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0089 - val_loss: 0.0138
# Epoch 92/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 93/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0090 - val_loss: 0.0093
# Epoch 94/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0090 - val_loss: 0.0105
# Epoch 95/200
# 277/277 [==============================] - 198s 714ms/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 96/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0089 - val_loss: 0.0089
# Epoch 97/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 98/200
# 277/277 [==============================] - 198s 714ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 99/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 100/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 101/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0088 - val_loss: 0.0100
# Epoch 102/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0089 - val_loss: 0.0101
# Epoch 103/200
# 277/277 [==============================] - 197s 709ms/step - loss: 0.0087 - val_loss: 0.0090
# Epoch 104/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0087 - val_loss: 0.0093
# Epoch 105/200
# 277/277 [==============================] - 198s 714ms/step - loss: 0.0087 - val_loss: 0.0087
# Epoch 106/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 107/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0088 - val_loss: 0.0100
# Epoch 108/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 109/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0086 - val_loss: 0.0092
# Epoch 110/200
# 277/277 [==============================] - 198s 714ms/step - loss: 0.0085 - val_loss: 0.0084
# Epoch 111/200
# 277/277 [==============================] - 199s 720ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 112/200
# 277/277 [==============================] - 197s 710ms/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 113/200
# 277/277 [==============================] - 203s 731ms/step - loss: 0.0087 - val_loss: 0.0086
# Epoch 114/200
# 277/277 [==============================] - 204s 736ms/step - loss: 0.0085 - val_loss: 0.0089
# Epoch 115/200
# 277/277 [==============================] - 201s 726ms/step - loss: 0.0085 - val_loss: 0.0084
# Epoch 116/200
# 277/277 [==============================] - 196s 709ms/step - loss: 0.0084 - val_loss: 0.0088
# Epoch 117/200
# 277/277 [==============================] - 194s 700ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 118/200
# 277/277 [==============================] - 195s 703ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 119/200
# 277/277 [==============================] - 195s 703ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 120/200
# 277/277 [==============================] - 192s 695ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 121/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0085 - val_loss: 0.0099
# Epoch 122/200
# 277/277 [==============================] - 192s 694ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 123/200
# 277/277 [==============================] - 192s 694ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 124/200
# 277/277 [==============================] - 192s 694ms/step - loss: 0.0084 - val_loss: 0.0086
# Epoch 125/200
# 277/277 [==============================] - 193s 698ms/step - loss: 0.0085 - val_loss: 0.0084
# Epoch 126/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0085 - val_loss: 0.0094
# Epoch 127/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0085 - val_loss: 0.0091
# Epoch 128/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 129/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 130/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 131/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0083 - val_loss: 0.0084
# Epoch 132/200
# 277/277 [==============================] - 193s 698ms/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 133/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0083 - val_loss: 0.0095
# Epoch 134/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 135/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 136/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0082 - val_loss: 0.0087
# Epoch 137/200
# 277/277 [==============================] - 193s 697ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 138/200
# 277/277 [==============================] - 192s 694ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 139/200
# 277/277 [==============================] - 193s 697ms/step - loss: 0.0082 - val_loss: 0.0083
# Epoch 140/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0082 - val_loss: 0.0089
# Epoch 141/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 142/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0083 - val_loss: 0.0084
# Epoch 143/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0082 - val_loss: 0.0087
# Epoch 144/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 145/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0082 - val_loss: 0.0085
# Epoch 146/200
# 277/277 [==============================] - 193s 697ms/step - loss: 0.0082 - val_loss: 0.0082
# Epoch 147/200
# 277/277 [==============================] - 193s 697ms/step - loss: 0.0082 - val_loss: 0.0082
# Epoch 148/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0083 - val_loss: 0.0086
# Epoch 149/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0082 - val_loss: 0.0082
# Epoch 150/200
# 277/277 [==============================] - 193s 698ms/step - loss: 0.0081 - val_loss: 0.0081
# Epoch 151/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0089 - val_loss: 0.0102
# Epoch 152/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 153/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0084 - val_loss: 0.0086
# Epoch 154/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0083 - val_loss: 0.0087
# Epoch 155/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0083 - val_loss: 0.0084
# Epoch 156/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0082 - val_loss: 0.0086
# Epoch 157/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0082 - val_loss: 0.0089
# Epoch 158/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 159/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0081 - val_loss: 0.0082
# Epoch 160/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0082 - val_loss: 0.0087
# Epoch 161/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0081 - val_loss: 0.0087
# Epoch 162/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0081 - val_loss: 0.0082
# Epoch 163/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0081 - val_loss: 0.0089
# Epoch 164/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0081 - val_loss: 0.0085
# Epoch 165/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0081 - val_loss: 0.0083
# Epoch 166/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0081 - val_loss: 0.0083
# Epoch 167/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 168/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0085
# Epoch 169/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0081 - val_loss: 0.0082
# Epoch 170/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 171/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 172/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 173/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0082
# Epoch 174/200
# 277/277 [==============================] - 193s 697ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 175/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0081 - val_loss: 0.0081
# Epoch 176/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 177/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 178/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0079 - val_loss: 0.0083
# Epoch 179/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 180/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0082 - val_loss: 0.0082
# Epoch 181/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0081 - val_loss: 0.0089
# Epoch 182/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0079 - val_loss: 0.0082
# Epoch 183/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 184/200
# 277/277 [==============================] - 193s 696ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 185/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0079 - val_loss: 0.0081
# Epoch 186/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 187/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0079 - val_loss: 0.0083
# Epoch 188/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0079 - val_loss: 0.0082
# Epoch 189/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0079 - val_loss: 0.0082
# Epoch 190/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 191/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 192/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0088
# Epoch 193/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0078 - val_loss: 0.0080
# Epoch 194/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0080 - val_loss: 0.0089
# Epoch 195/200
# 277/277 [==============================] - 192s 693ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 196/200
# 277/277 [==============================] - 193s 697ms/step - loss: 0.0079 - val_loss: 0.0079
# Epoch 197/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0079 - val_loss: 0.0081
# Epoch 198/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0078 - val_loss: 0.0082
# Epoch 199/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0078 - val_loss: 0.0082
# Epoch 200/200
# 277/277 [==============================] - 192s 692ms/step - loss: 0.0079 - val_loss: 0.0083
